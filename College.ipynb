# %%
import pandas as pd

pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

# %%
colleges = pd.read_csv('/Users/carol/Downloads/college.csv')

# %%
colleges
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
colleges[0:3]
# Out:
#    unitid                     institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing 25th percentile
# ...

# %%
colleges.count()
# Out:
# unitid                                                          352
# institution name                                                352
# year                                                            352
# IC2013.Fall reporting period for applicant and admissions       352
# IC2013.Applicants total                                         352
# IC2013.Applicants men                                           348
# IC2013.Applicants women                                         352
# IC2013.Admissions total                                         352
# IC2013.Admissions men                                           347
# IC2013.Admissions women                                         352
# IC2013.Enrolled total                                           352
# IC2013.Enrolled  men                                            347
# IC2013.Enrolled  women                                          352
# DRVIC2013.Percent admitted - total                              352
# ...

# %%
leastcompetitive = colleges[colleges['DRVIC2013.Percent admitted - men'] > 50]
leastcompetitive[:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
leastcompetitive.count()
# Out:
# unitid                                                          204
# institution name                                                204
# year                                                            204
# IC2013.Fall reporting period for applicant and admissions       204
# IC2013.Applicants total                                         204
# IC2013.Applicants men                                           204
# IC2013.Applicants women                                         204
# IC2013.Admissions total                                         204
# IC2013.Admissions men                                           204
# IC2013.Admissions women                                         204
# IC2013.Enrolled total                                           204
# IC2013.Enrolled  men                                            204
# IC2013.Enrolled  women                                          204
# DRVIC2013.Percent admitted - total                              204
# ...

# %%
morecompetitive = colleges[colleges['DRVIC2013.Percent admitted - men'] <= 50]
morecompetitive[:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
morecompetitive.count()
# Out:
# unitid                                                          138
# institution name                                                138
# year                                                            138
# IC2013.Fall reporting period for applicant and admissions       138
# IC2013.Applicants total                                         138
# IC2013.Applicants men                                           138
# IC2013.Applicants women                                         138
# IC2013.Admissions total                                         138
# IC2013.Admissions men                                           138
# IC2013.Admissions women                                         138
# IC2013.Enrolled total                                           138
# IC2013.Enrolled  men                                            138
# IC2013.Enrolled  women                                          138
# DRVIC2013.Percent admitted - total                              138
# ...

# %%
crazycompetitive = colleges[colleges['DRVIC2013.Percent admitted - men'] <= 10]
crazycompetitive[:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
crazycompetitive.count()
# Out:
# unitid                                                          13
# institution name                                                13
# year                                                            13
# IC2013.Fall reporting period for applicant and admissions       13
# IC2013.Applicants total                                         13
# IC2013.Applicants men                                           13
# IC2013.Applicants women                                         13
# IC2013.Admissions total                                         13
# IC2013.Admissions men                                           13
# IC2013.Admissions women                                         13
# IC2013.Enrolled total                                           13
# IC2013.Enrolled  men                                            13
# IC2013.Enrolled  women                                          13
# DRVIC2013.Percent admitted - total                              13
# ...

# %%
crazycompetitive['IC2013.SAT Critical Reading 25th percentile score']
# Out:
# 12     720
# 49     700
# 80     720
# 121    570
# 133    700
# 137    680
# 174    670
# 176    700
# 187    690
# 188    610
# 217    580
# 342    680
# 347    690
# Name: IC2013.SAT Critical Reading 25th percentile score, dtype: int64

# %%
is_above25 = crazycompetitive['IC2013.SAT Critical Reading 25th percentile score'] <= 630
crazycompetitive[is_above25][:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
is_above25 = colleges['IC2013.SAT Critical Reading 25th percentile score'] <= 630
is_min500 = colleges['IC2013.SAT Critical Reading 25th percentile score'] >= 500
colleges[is_above25 & is_min500][:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
is_above25 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] <= 630
is_min500 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] >= 500
morecompetitive[is_above25 & is_min500][:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
is_location = morecompetitive['HD2013.State abbreviation'] == 'California'
is_jakeabove25 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] <= 630
is_min500 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] >= 500
morecompetitive[is_jakeabove25 & is_min500 & is_location][:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
is_location = morecompetitive['HD2013.State abbreviation'] == 'Texas'
is_jakeabove25 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] <= 630
is_min500 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] >= 500
morecompetitive[is_jakeabove25 & is_min500 & is_location][:]
# Out:
#      unitid                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing 25th percentile
# ...

# %%
is_location = morecompetitive['HD2013.State abbreviation'] == 'Michigan'
is_jakeabove25 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] <= 630
is_min500 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] >= 500
morecompetitive[is_jakeabove25 & is_min500 & is_location][:]
# Out:
#      unitid                  institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing 25th percentile 
# ...

# %%
is_location = morecompetitive['HD2013.State abbreviation'] == 'Minnesota'
is_jakeabove25 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] <= 630
is_min500 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] >= 500
morecompetitive[is_jakeabove25 & is_min500 & is_location][:]
# Out:
#      unitid                     institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing 25th percenti
# ...

# %%
#is_location = morecompetitive['HD2013.State abbreviation'] == 'Minnesota'
is_jakeabove75 = colleges['IC2013.SAT Critical Reading 75th percentile score'] <= 630
is_min500 = colleges['IC2013.SAT Critical Reading 25th percentile score'] >= 500
colleges[is_jakeabove75 & is_min500][:]
# Out:
#      unitid                               institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing 25t
# ...

# %%
is_jakeabove25 = colleges['IC2013.SAT Critical Reading 25th percentile score'] <= 630
#is_jakeabove75 = colleges['IC2013.SAT Critical Reading 75th percentile score'] <= 630
is_min600 = colleges['IC2013.SAT Critical Reading 25th percentile score'] >= 600
colleges[is_jakeabove25 & is_min600][:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
colleges[is_jakeabove25 & is_min600][:].count()
# Out:
# unitid                                                          32
# institution name                                                32
# year                                                            32
# IC2013.Fall reporting period for applicant and admissions       32
# IC2013.Applicants total                                         32
# IC2013.Applicants men                                           31
# IC2013.Applicants women                                         32
# IC2013.Admissions total                                         32
# IC2013.Admissions men                                           31
# IC2013.Admissions women                                         32
# IC2013.Enrolled total                                           32
# IC2013.Enrolled  men                                            31
# IC2013.Enrolled  women                                          32
# DRVIC2013.Percent admitted - total                              32
# ...

# %%
is_jakeabove25 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] <= 630
#is_jakeabove75 = colleges['IC2013.SAT Critical Reading 75th percentile score'] <= 630
is_min600 = morecompetitive['IC2013.SAT Critical Reading 25th percentile score'] >= 600
morecompetitive[is_jakeabove25 & is_min600][:]
# Out:
#      unitid                                   institution name  year IC2013.Fall reporting period for applicant and admissions  IC2013.Applicants total  IC2013.Applicants men  IC2013.Applicants women  IC2013.Admissions total  IC2013.Admissions men  IC2013.Admissions women  IC2013.Enrolled total  IC2013.Enrolled  men  IC2013.Enrolled  women  DRVIC2013.Percent admitted - total  DRVIC2013.Percent admitted - men IC2013.Fall reporting period for SAT/ACT test scores  IC2013.SAT Critical Reading 25th percentile score  IC2013.SAT Critical Reading 75th percentile score  IC2013.SAT Math 25th percentile score  IC2013.SAT Math 75th percentile score  IC2013.SAT Writing 25th percentile score  IC2013.SAT Writing 75th percentile score  IC2013.ACT Composite 25th percentile score  IC2013.ACT Composite 75th percentile score  IC2013.ACT English 25th percentile score  IC2013.ACT English 75th percentile score  IC2013.ACT Math 25th percentile score  IC2013.ACT Math 75th percentile score  IC2013.ACT Writing
# ...

# %%
morecompetitive[is_jakeabove25 & is_min600][:].count()
# Out:
# unitid                                                          24
# institution name                                                24
# year                                                            24
# IC2013.Fall reporting period for applicant and admissions       24
# IC2013.Applicants total                                         24
# IC2013.Applicants men                                           24
# IC2013.Applicants women                                         24
# IC2013.Admissions total                                         24
# IC2013.Admissions men                                           24
# IC2013.Admissions women                                         24
# IC2013.Enrolled total                                           24
# IC2013.Enrolled  men                                            24
# IC2013.Enrolled  women                                          24
# DRVIC2013.Percent admitted - total                              24
# ...
